# %% [markdown]
# # Учебное пособие
#
# Для взаимодействия с этим руководством **требуется ключ API**. Если у вас нет ключа API, вы можете зарегистрировать его через [Anthropic Console](https://console.anthropic.com/) или вместо этого просмотреть наш [статический ключ ответа руководства](https://docs.google.com/spreadsheets/u/0/d/1jIxjzUWG-6xBVIa2ay6yDpLyeuOh_hR_ZB75a47KX_E/edit).

# %% [markdown]
# ## Как начать
#
# 1. Клонируйте этот репозиторий на свой локальный компьютер.
#
# 2. Установите необходимые зависимости, выполнив следующую команду:

# %%
# %pip install anthropic

# %% [markdown]
# 3. Настройте ключ API и имя модели. Замените `"your_api_key_here"` на ваш фактический ключ Anthropic API.

# %%
API_KEY = "your_api_key_here"
MODEL_NAME = "claude-3-haiku-20240307"

# Stores the API_KEY & MODEL_NAME variables for use across notebooks within the IPython store
# %store API_KEY
# %store MODEL_NAME

# %% [markdown]
# 4. Запустите ячейки блокнота по порядку, следуя предоставленным инструкциям.

# %% [markdown]
# ---
#
# ## Примечания и советы по использованию 💡
#
# - В этом курсе используется Claude 3 Haiku с температурой 0. Подробнее о температуре мы поговорим позже в этом курсе. Пока достаточно понять, что эти настройки дают более детерминированные результаты. Все методы быстрого проектирования в этом курсе также применимы к устаревшим моделям Claude предыдущего поколения, таким как Claude 2 и Claude Instant 1.2.
#
# - Вы можете использовать Shift + Enter для выполнения ячейки и перехода к следующей.
#
# - Когда вы дойдете до конца страницы руководства, перейдите к следующему пронумерованному файлу в папке или к следующей пронумерованной папке, если вы закончили работу с содержимым этого файла главы.
#
# ### Anthropic SDK и API сообщений
# В этом руководстве мы будем использовать [Anthropic python SDK](https://docs.anthropic.com/claude/reference/client-sdks) и [Messages API](https://docs.anthropic.com/claude/reference/messages_post).
#
# Ниже приведен пример того, как будет выглядеть запуск приглашения в этом руководстве. Сначала мы создаем get_completion — вспомогательную функцию, которая отправляет запрос Клоду и возвращает сгенерированный Клодом ответ. Запустите эту ячейку сейчас.

# %%
import anthropic

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# Теперь мы напишем пример приглашения для Клода и распечатаем вывод Клода, запустив нашу вспомогательную функцию get_completion. Запуск ячейки ниже приведет к распечатке ответа от Клода под ней.
#
# Не стесняйтесь экспериментировать со строкой подсказки, чтобы получить разные ответы от Клода.

# %%
# Prompt
prompt = "Hello, Claude!"

# Get Claude's response
print(get_completion(prompt))

# %% [markdown]
# Определенные ранее переменные API_KEY и MODEL_NAME будут использоваться на протяжении всего руководства. Просто не забудьте запустить ячейки для каждой страницы руководства сверху вниз.
